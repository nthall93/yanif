# %%
import yanif
g = yanif.game()
# Out:
# Enter amount of players: 2
# Enter player 1's name: Nick
# Enter player 2's name: Shireen
# Click 'y' if you would like to start playing: y
#
#
# --------ROUND 1--------
# Nick to deal
# Enter player that called Yanif: Shireen
# Nick needs 25 for go back
# Enter Nick's Score: 7
# Enter Shireen's Score: 1
# Shireen successfully called Yanif
#              Nick                                                          \
#       Round Score Total Score Go Back Count Yanif Count False Yanif Count
# Round
# 1               7           7             0           0                 0
#
#           Shireen
#       Round Score Total Score Go Back Count Yanif Count False Yanif Count
# Round
# 1               1           0             0           1                 0
# C:\Users\Nick\Documents\Python Scripts\yanif\yanif.py:160: UserWarning: Attempting to set identical left == right == 1 results in singular transformations; automatically expanding.
#   ax.set_xlim([1,self.round])
# ...

# %%
g.scoreBoard.to_csv('game01.csv')
